# %% [markdown]
# # Lista de Exercício #01

# %% [markdown]
# ## Coleta e amostragem de dados

# %% [markdown]
# 01. Crie um programa que solicite à pessoa usuária digitar seu nome, e imprima “Olá, [nome]!”.

# %%
nome = input('Digite seu nome')
print(f'Olá, {nome}')
# Out:
# Olá, João Pedro

# %% [markdown]
# 02. Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima “Olá, [nome], você tem [idade] anos.”.

# %%
nome = str(input('Digite seu nome: '))
idade = int(input('Digite sua idade: '))
print(f'Olá, {nome}, voccê tem {idade} anos.')
# Out:
# Olá, João Pedro, voccê tem 28 anos.

# %% [markdown]
# 03. Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima “Olá, [nome], você tem [idade] anos e mede [altura] metros!”.

# %%
nome = str(input('Digite seu nome: '))
idade = int(input('Digite sua idade: '))
altura = float(input('Digite sua altura: '))
print(f'Olá, {nome}, voccê tem {idade} anos e mede {altura} centímetros.')
# Out:
# Olá, João Pedro, voccê tem 28 anos e mede 165.7 metros.

# %% [markdown]
# ## Calculadora com operadores

# %% [markdown]
# 01. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
resultado = num1 + num2
resultado
# Out:
# 4

# %% [markdown]
# 02. Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
num3 = int(input('Digite o terceiro número: '))
resultado = num1 + num2 + num3
resultado
# Out:
# 281

# %% [markdown]
# 03. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
resultado = num1 - num2
resultado
# Out:
# 114

# %% [markdown]
# 04. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
resultado = num1 * num2
resultado
# Out:
# 2052

# %% [markdown]
# 05. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser `0`.

# %%
num = int(input('Digite o numerador: '))
denom = int(input('Digite o denominador (não pode ser 0): '))
resultado = num / denom
resultado
# Out:
# 7.0

# %% [markdown]
# 06. Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
resultado = num1 ** num2
resultado
# Out:
# 25

# %% [markdown]
# 07. Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser `0`.

# %%
num = int(input('Digite o numerador: '))
denom = int(input('Digite o denominador (não pode ser 0): '))
resultado = num // denom
resultado
# Out:
# 7

# %% [markdown]
# 08. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
num = int(input('Digite o numerador: '))
denom = int(input('Digite o denominador (não pode ser 0): '))
resultado = num % denom
resultado
# Out:
# 1

# %% [markdown]
# 09. Crie um código que solicita 3 notas de um estudante e imprima a média das notas.

# %%
num1 = int(input('Digite a primeira nota: '))
num2 = int(input('Digite a segunda nota: '))
num3 = int(input('Digite a terceira nota: '))
resultado = (num1 + num2 + num3) / 3
resultado
# Out:
# 5.666666666666667

# %% [markdown]
# 10. Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.

# %%
num1 = int(input('Digite a primeira nota: '))
num2 = int(input('Digite a segunda nota: '))
num3 = int(input('Digite a terceira nota: '))
num4 = int(input('Digite a quarta nota: '))
resultado = ((num1 * 1) + (num2 * 2) + (num3 * 3) + (num4 * 4)) / (1 + 2 + 3 + 4)
resultado
# Out:
# 6.6

# %% [markdown]
# ## Editando textos

# %% [markdown]
# 01. Crie uma variável chamada `“frase”` e atribua a ela uma string de sua escolha. Em seguida, imprima a frase na tela.

# %%
frase = 'Linkin Park é uma das melhores bandas que existem.'
print(frase)
# Out:
# Linkin Park é uma das melhores bandas que existem.

# %% [markdown]
# 02. Crie um código que solicite uma frase e depois imprima a frase na tela.

# %%
frase = input('Digite uma frase: ')
print(frase)
# Out:
# Linkin Park é uma das melhores bandas que existem.

# %% [markdown]
# 03. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras maiúsculas.

# %%
frase = input('Digite uma frase: ')
frase.upper()
# Out:
# 'LINKIN PARK É UMA DAS MELHORES BANDAS QUE EXISTEM.'

# %% [markdown]
# 04. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras minúsculas.

# %%
frase = input('Digite uma frase: ')
frase.lower()
# Out:
# 'linkin park é uma das melhores bandas que existem.'

# %% [markdown]
# 05. Crie uma variável chamada `“frase”` e atribua a ela uma string de sua escolha. Em seguida, imprima a frase sem espaços em branco no início e no fim.

# %%
frase = ' Linkin Park é uma das melhores bandas que existem. '
frase.strip()
# Out:
# 'Linkin Park é uma das melhores bandas que existem.'

# %% [markdown]
# 06. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim.

# %%
frase = input('Digite uma frase: ')
frase.strip()
# Out:
# 'Linkin Park é uma das melhores bandas que existem.'

# %% [markdown]
# 07. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim e em letras minúsculas.

# %%
frase = input('Digite uma frase: ')
frase.strip().upper()
# Out:
# 'LINKIN PARK É UMA DAS MELHORES BANDAS QUE EXISTEM.'

# %% [markdown]
# 08. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais `“e”` trocadas pela letra `“f”`.

# %%
frase = input('Digite uma frase: ')
frase.replace('e','f')
# Out:
# 'Linkin Park é uma das mflhorfs bandas quf fxistfm'

# %% [markdown]
# 09. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais `“a”` trocadas pela caractere `“@”`.

# %%
frase = input('Digite uma frase: ')
frase.replace('a','@')
# Out:
# 'Linkin P@rk é um@ d@s melhores b@nd@s que existem.'

# %% [markdown]
# 10. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as consoantes `“s”` trocadas pelo caractere `“$”`.

# %%
frase = input('Digite uma frase: ')
frase.replace('s','$')
# Out:
# 'Linkin Park é uma da$ melhore$ banda$ que exi$tem.'
